# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Defining function to be used 
def f(x):
    return x**3*np.sin(x)

x = np.linspace(0,10,101)
y = f(x)

plt.plot(x, y)
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
# Defining Variables
a = 1
b = 4 
m = (a + b)/2
eps = 
val1 = f(a)*f(m)
val2 = f(b)*f(m)
print(f(a))
print(f(b))
print(f(m))

diff = b - a

# Attempt at bisection method 
while diff < eps: 
    if (val1 < 0): 
        temp1 = m 
        b = temp1
    elif (val2 < 0):
        temp2 = m 
        a = temp2 
    else: 
        print(m)
        break
# Out:
#   File &quot;&lt;ipython-input-3-1a8b02ae7dda&gt;&quot;, line 5
#     eps =
#           ^
# SyntaxError: invalid syntax
