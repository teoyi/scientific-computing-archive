# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
v_0 = 1000
v = np.arange(0,1500) 
A = 1 
s_v = A * v**2/v_0**2 * np.exp(-v/v_0)
i_0 = A * (v/v_0)*-1 

plt.plot(v, s_v)
plt.plot(v, i_0)
# plt.ylim = ([-1000, 1000])
plt.xlim = ([0, 10])
plt.show()
