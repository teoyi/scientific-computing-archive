# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df_s = pd.read_csv('short_data.csv')
df_p1 = pd.read_csv('point1stepN.csv')
df_p1a = pd.read_csv('point1N_analysis.csv')

# %%
print(df_p1)
# Out:
#        Time - Plot 0  Amplitude - Plot 0
# 0            0.00000            0.005569
# 1            0.00001            0.005569
# 2            0.00002            0.005368
# 3            0.00003            0.005368
# 4            0.00004            0.005167
# ...              ...                 ...
# 49995        0.49995            0.015016
# 49996        0.49996            0.015619
# 49997        0.49997            0.015217
# 49998        0.49998            0.015217
# 49999        0.49999            0.015820
#
# [50000 rows x 2 columns]

# %%
plt.plot(df_s['Time - Plot 0'], df_s['Amplitude - Plot 0'], color = 'black', linewidth = 0.5)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (V)')
plt.savefig('shortpeak.png')
plt.show()

# %%
# Plot of measured fringes 
plt.plot(df_p1['Time - Plot 0'], df_p1['Amplitude - Plot 0'], color = 'black', linewidth = 0.5)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (V)')
plt.savefig('longpeak.png')
plt.show()

# %%
# Plotting peak analysis of point 1 step 
plt.plot(df_p1a['index # - Plot 0'], df_p1a['Amplitude - Plot 0'], color = 'black', linewidth = 0.5)
plt.plot(df_p1a['index # - Plot 1'], df_p1a['Amplitude - Plot 1'], color = 'red', linewidth = 0.5)
plt.plot(df_p1a['index # - Plot 2'], df_p1a['Amplitude - Plot 2'], color = 'blue', linewidth = 0.5)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (V)')
plt.savefig('peakanal.png')
plt.show()

# %%
# df_p1a.iloc[10000:13000]
plt.plot(df_p1a['index # - Plot 0'].iloc[10000:11000], df_p1a['Amplitude - Plot 0'].iloc[10000:11000], color = 'black')
plt.plot(df_p1a['index # - Plot 1'].iloc[10000:11000], df_p1a['Amplitude - Plot 1'].iloc[10000:11000], color = 'red')
plt.plot(df_p1a['index # - Plot 2'].iloc[10000:11000], df_p1a['Amplitude - Plot 2'].iloc[10000:11000], color = 'blue')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (V)')
plt.savefig('peakanalzoom.png')
plt.show()
